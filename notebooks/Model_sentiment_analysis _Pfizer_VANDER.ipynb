# %%
# Versão do python

from platform import python_version

print('Versão python neste Jupyter Notebook:', python_version())
# Out:
# Versão python neste Jupyter Notebook: 3.8.8

# %%
# Importação das bibliotecas 

import pandas as pd # Pandas carregamento csv
import numpy as np # Numpy para carregamento cálculos em arrays multidimensionais

# Visualização de dados
import seaborn as sns
import matplotlib as m
import matplotlib as mpl
import matplotlib.pyplot as plt
import plotly
import plotly.express as px

# Carregar as versões das bibliotecas
import watermark

# Warnings retirar alertas 
import warnings
warnings.filterwarnings("ignore")

# %%
# NLTK para NLP
import nltk
import re

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')
nltk.download("stopwords")
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Administrador\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Administrador\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Administrador\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Versões das bibliotecas

# %reload_ext watermark
# %watermark -a "Versões das bibliotecas" --iversions
# Out:
# Author: Versões das bibliotecas
#
# sys       : 3.8.8 (default, Apr 13 2021, 15:08:03) [MSC v.1916 64 bit (AMD64)]
# numpy     : 1.20.1
# seaborn   : 0.11.1
# watermark : 2.3.0
# nltk      : 3.6.1
# re        : 2.2.1
# matplotlib: 3.3.4
# pandas    : 1.2.4
# plotly    : 5.6.0

# %%
# Configuração para os gráficos largura e layout dos graficos

plt.style.use('fivethirtyeight')

# %%
# Carregando a base de dados

df = pd.read_csv("Vaccine Tweets-Pfizer.csv")
df
# Out:
#       Unnamed: 0                                              Tweet  \
# 0              0  Historically there have been barriers in the h...
# 1              1  Honored and PfizerProud to see the trust that ...
# 2              2  COVID19 illuminated the need to improve equity...
# 3              3  Today we published a landmark study on diversi...
# 4              4  They volunteered🤚 to help change the world🌎 . ...
# ...          ...                                                ...
# 2850        2851  Did you know we launched a database to track a...
# 2851        2852  We’re at AtlanticCSR to talk about partnership...
# 2852        2853  Gastric cancer, also known as stomachcancer, i...
# 2853        2854  Learn about the value of vaccines in preventin...
# 2854        2855  Bacteria like S. aureus are becoming increasin...
#
#       Subjectivity  Polarity     Score
# 0         0.450000     0.350  Positive
# 1         0.066667     0.000   Neutral
# 2         0.000000     0.000   Neutral
# 3         0.000000     0.000   Neutral
# 4         0.300000     0.200  Positive
# ...            ...       ...       ...
# 2850      0.800000     0.400  Positive
# 2851      0.500000     0.500  Positive
# 2852      0.500000     0.100  Positive
# 2853      0.000000     0.000   Neutral
# 2854      0.425000     0.175  Positive
#
# [2855 rows x 5 columns]

# %%
# Exibido 5 primeiros dados
df.head()
# Out:
#    Unnamed: 0                                              Tweet  \
# 0           0  Historically there have been barriers in the h...
# 1           1  Honored and PfizerProud to see the trust that ...
# 2           2  COVID19 illuminated the need to improve equity...
# 3           3  Today we published a landmark study on diversi...
# 4           4  They volunteered🤚 to help change the world🌎 . ...
#
#    Subjectivity  Polarity     Score
# 0      0.450000      0.35  Positive
# 1      0.066667      0.00   Neutral
# 2      0.000000      0.00   Neutral
# 3      0.000000      0.00   Neutral
# 4      0.300000      0.20  Positive

# %%
# Exibido 5 últimos dados 
df.tail()
# Out:
#       Unnamed: 0                                              Tweet  \
# 2850        2851  Did you know we launched a database to track a...
# 2851        2852  We’re at AtlanticCSR to talk about partnership...
# 2852        2853  Gastric cancer, also known as stomachcancer, i...
# 2853        2854  Learn about the value of vaccines in preventin...
# 2854        2855  Bacteria like S. aureus are becoming increasin...
#
#       Subjectivity  Polarity     Score
# 2850         0.800     0.400  Positive
# 2851         0.500     0.500  Positive
# 2852         0.500     0.100  Positive
# 2853         0.000     0.000   Neutral
# 2854         0.425     0.175  Positive

# %%
# Número de linhas e colunas
df.shape

# %%
# Exibido tipos de dados
df.dtypes

# %%
# Verificando informações das variaveis
df.info()

# %%
# Total de colunas e linhas 

print("Números de linhas: {}" .format(df.shape[0]))
print("Números de colunas: {}" .format(df.shape[1]))

# %%
# Exibindo valores ausentes e valores únicos

print("\nMissing values :  ", df.isnull().sum().values.sum())
print("\nUnique values :  \n",df.nunique())

# %%
# Verificando a polaridade

df.Polarity.value_counts()

# %%
# Renomeando colunas
df.columns = ["Usuario",
              "Text",
              "Subjetividade",
              "Polaridade",
              "Sentimento"]
df.head()
# Out:
#    Usuario                                               Text  Subjetividade  \
# 0        0  Historically there have been barriers in the h...       0.450000
# 1        1  Honored and PfizerProud to see the trust that ...       0.066667
# 2        2  COVID19 illuminated the need to improve equity...       0.000000
# 3        3  Today we published a landmark study on diversi...       0.000000
# 4        4  They volunteered🤚 to help change the world🌎 . ...       0.300000
#
#    Polaridade Sentimento
# 0        0.35   Positive
# 1        0.00    Neutral
# 2        0.00    Neutral
# 3        0.00    Neutral
# 4        0.20   Positive

# %%
# Exibindo estatísticas descritivas visualizar alguns detalhes estatísticos básicos como percentil, média, padrão, etc. 
# De um quadro de dados ou uma série de valores numéricos.

df.describe().T
# Out:
#                 count         mean         std  min    25%          50%  \
# Usuario        2855.0  1427.698424  824.676764  0.0  713.5  1428.000000
# Subjetividade  2855.0     0.381149    0.335380  0.0    0.0     0.400000
# Polaridade     2855.0     0.172970    0.260051 -0.8    0.0     0.066667
#
#                    75%     max
# Usuario        2141.50  2855.0
# Subjetividade     0.60     1.0
# Polaridade        0.35     1.0

# %%
df
# Out:
#       Usuario                                               Text  \
# 0           0  Historically there have been barriers in the h...
# 1           1  Honored and PfizerProud to see the trust that ...
# 2           2  COVID19 illuminated the need to improve equity...
# 3           3  Today we published a landmark study on diversi...
# 4           4  They volunteered🤚 to help change the world🌎 . ...
# ...       ...                                                ...
# 2850     2851  Did you know we launched a database to track a...
# 2851     2852  We’re at AtlanticCSR to talk about partnership...
# 2852     2853  Gastric cancer, also known as stomachcancer, i...
# 2853     2854  Learn about the value of vaccines in preventin...
# 2854     2855  Bacteria like S. aureus are becoming increasin...
#
#       Subjetividade  Polaridade Sentimento
# 0          0.450000       0.350   Positive
# 1          0.066667       0.000    Neutral
# 2          0.000000       0.000    Neutral
# 3          0.000000       0.000    Neutral
# 4          0.300000       0.200   Positive
# ...             ...         ...        ...
# 2850       0.800000       0.400   Positive
# 2851       0.500000       0.500   Positive
# 2852       0.500000       0.100   Positive
# 2853       0.000000       0.000    Neutral
# 2854       0.425000       0.175   Positive
#
# [2855 rows x 5 columns]

# %%
# Verificando o total de sentimentos

df_x = df.Sentimento.value_counts().sort_values()
df_x
# Out:
# Negative     227
# Neutral     1126
# Positive    1502
# Name: Sentimento, dtype: int64

# %%
# Gráfico de Análise sentimento

plt.figure(figsize=(20.5,15))

plt.title("Análise sentimento das frases")
ax = sns.countplot(df["Sentimento"])
plt.xlabel("Sentimento")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico polaridade das frases

plt.figure(figsize=(12.8,6))

plt.title("Polaridade das frases")
ax = sns.kdeplot(df["Polaridade"])
plt.xlabel("Polaridade")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico subjetividade e sentimento

plt.figure(figsize=(12.8,6))

ax = sns.boxplot(x="Subjetividade", y="Sentimento", data = df)
plt.title("Sentimento das frases")
plt.xlabel("Subjetividade")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico de polaridade sentimento

plt.figure(figsize=(12.8,6))

ax = sns.boxplot(x="Polaridade", y="Sentimento", data = df)
plt.title("Sentimento das frases")
plt.xlabel("Subjetividade")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico scatterplot de sentimento
plt.figure(figsize=(12.8,6))

ax = sns.scatterplot(x="Subjetividade", y="Polaridade", data=df, hue="Sentimento")
plt.title("Polaridade")
plt.xlabel("Subjetividade")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico de sentimento e subjetividade
plt.figure(figsize=(12.8,6))

ax = sns.barplot(x="Subjetividade", y="Sentimento", data = df, hue="Sentimento")
plt.title("Polaridade")
plt.xlabel("Subjetividade")
plt.ylabel("Total")
# Out:
# Text(0, 0.5, 'Total')

# %%
# Gráfico nuvem de palavras
import itertools
from wordcloud import WordCloud

words = ' '.join([tweet for tweet in df['Text']])
wordCloud = WordCloud(width=600, height=400).generate(words)

plt.figure(figsize=(18.8, 16))
plt.imshow(wordCloud)
plt.show()

# %%
plt.figure(figsize=(20.5, 15))

ax = plt.pie(x = df_x, labels=df_x.index, autopct = '%1.1f%%', explode = [0.03, 0.03, 0.08])
plt.title('Gráfico de pizza - Sentimentos')

plt.show()

# %%
# Verificando as colunas do dataset

df.columns
# Out:
# Index(['Usuario', 'Text', 'Subjetividade', 'Polaridade', 'Sentimento'], dtype='object')

# %%
# Definindo os dados para análise

df = df[['Sentimento', 'Text']]
df.head()
# Out:
#   Sentimento                                               Text
# 0   Positive  Historically there have been barriers in the h...
# 1    Neutral  Honored and PfizerProud to see the trust that ...
# 2    Neutral  COVID19 illuminated the need to improve equity...
# 3    Neutral  Today we published a landmark study on diversi...
# 4   Positive  They volunteered🤚 to help change the world🌎 . ...

# %%
# Análise de sentimento nas frases

# Importando a biblioteca vader sentiment, sentiment intensity analyzer
import nltk
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer 
from nltk.sentiment.vader import SentimentIntensityAnalyzer

# Modelo da análise de sentimento
model = SentimentIntensityAnalyzer()

# Função das frases
def data_model(df):
    
    # Modelo polaridade e score das frases
    model_set = model.polarity_scores(df) 
    
    # Print análise de sentimento
    print("{:-<40} {}".format(df, str(model_set)))

# Verificando sentimento
data_model("O voo da United foi uma experiência ruim")
# Out:
# O voo da United foi uma experiência ruim {'neg': 0.0, 'neu': 0.682, 'pos': 0.318, 'compound': 0.4215}

# %%
# %time

x = 0

# Modelo
model_1 = []

# Lendo os dados do score
while(x<len(df)):
    
    # Modelo
    y = model.polarity_scores(df.iloc[x]['Text'])
    
    # Armazenando no modelo
    model_1.append(y["compound"])
    x = x + 1
    
# Adicionando no array 
model_1 = np.array(model_1)

# Lendo o total de frases do modelo
len(model_1)
# Out:
# Wall time: 0 ns
# 2855

# %%
# Score do modelo

df["Score_vader"] = model_1
df.head(20)
# Out:
#    Sentimento                                               Text  Score_vader
# 0    Positive  Historically there have been barriers in the h...       0.3182
# 1     Neutral  Honored and PfizerProud to see the trust that ...       0.7964
# 2     Neutral  COVID19 illuminated the need to improve equity...       0.4404
# 3     Neutral  Today we published a landmark study on diversi...       0.0772
# 4    Positive  They volunteered🤚 to help change the world🌎 . ...       0.8316
# 5    Positive  Bladder cancer is most common in patients over...       0.1689
# 6    Negative  Since 1971  has supported the mental health of...       0.5574
# 7     Neutral  We are resolute in support of the  TimeToActCa...       0.7184
# 8    Positive  At Pfizer, we believe partnership is key to ad...       0.7096
# 9     Neutral  Our novel prediction model, derived from machi...       0.3182
# 10    Neutral  🗣️On EuropeanStrokeAwarenessDay today, in part...       0.0000
# 11    Neutral  BREAKING: Today, with , we announced  expanded...      -0.3818
# 12    Neutral  The Pfizer-BioNTech COVID-19 Vaccine has not b...      -0.1695
# 13    Neutral  Congratulations to , whose ScienceBasedTargets...       0.8074
# 14    Neutral  Our Chief Development Officer  will be recogni...       0.5423
# 15   Positive  What progress looks like: &gt;1 million less c...      -0.3133
# 16    Neutral  You’ve got questions, we’ve got answers. Visit...       0.0000
# 17    Neutral  BREAKING: Today, with , we initiated the submi...       0.4767
# 18    Neutral  Pfizer's Morris Birnbaum, MD, PhD, recently jo...       0.0000
# 19    Neutral  Covid made it necessary for researchers and sc...       0.2732

# %%
# %time

x = 0

# Adicionando uma list
pred = []

# Definindo sentimento positivo
while(x<len(df)):
    if ((df.iloc[x]["Score_vader"] >= 0.7)):
        pred.append("Positivo")
        x = x + 1
    
    # Definindo sentimento neutro
    elif((df.iloc[x]["Score_vader"] > 0) & (df.iloc[x]["Score_vader"] < 0.7)):
        pred.append("Neutro")
        x = x + 1
    
    # Definindo sentimento negativo
    elif ((df.iloc[x]["Score_vader"] <= 0)):
        pred.append("Negativo")
        x = x + 1
# Out:
# Wall time: 0 ns

# %%
# Visualizando a análise de sentimento

df["Previsão"] = pred
len(df['Previsão'])

# Visualizando total de sentimentos
df.head(50)
# Out:
#    Sentimento                                               Text  Score_vader  \
# 0    Positive  Historically there have been barriers in the h...       0.3182
# 1     Neutral  Honored and PfizerProud to see the trust that ...       0.7964
# 2     Neutral  COVID19 illuminated the need to improve equity...       0.4404
# 3     Neutral  Today we published a landmark study on diversi...       0.0772
# 4    Positive  They volunteered🤚 to help change the world🌎 . ...       0.8316
# 5    Positive  Bladder cancer is most common in patients over...       0.1689
# 6    Negative  Since 1971  has supported the mental health of...       0.5574
# 7     Neutral  We are resolute in support of the  TimeToActCa...       0.7184
# 8    Positive  At Pfizer, we believe partnership is key to ad...       0.7096
# 9     Neutral  Our novel prediction model, derived from machi...       0.3182
# 10    Neutral  🗣️On EuropeanStrokeAwarenessDay today, in part...       0.0000
# 11    Neutral  BREAKING: Today, with , we announced  expanded...      -0.3818
# 12    Neutral  The Pfizer-BioNTech COVID-19 Vaccine has not b...      -0.1695
# 13    Neutral  Congratulations to , whose ScienceBasedTargets...       0.8074
# 14    Neutral  Our Chief Development Officer  will be recogni...       0.5423
# 15   Positive  What progress looks like: &gt;1 million less c...      -0.3133
# 16    Neutral  You’ve got questions, we’ve got answers. Visit...       0.0000
# 17    Neutral  BREAKING: Today, with , we initiated the submi...       0.4767
# 18    Neutral  Pfizer's Morris Birnbaum, MD, PhD, recently jo...       0.0000
# 19    Neutral  Covid made it necessary for researchers and sc...       0.2732
# 20    Neutral  With , we signed a memorandum of understanding...       0.0000
# 21    Neutral  On International Day of the Midwife, learn abo...       0.2960
# 22   Positive  Certain minority populations are 4x more likel...       0.5256
# 23   Positive  Happy to see doses of the Pfizer-BioNTech COVI...       0.5719
# 24    Neutral  Our Chief Development Officer  will be recogni...       0.5423
# 25    Neutral  Today we have announced we are mobilizing the ...       0.7003
# 26   Negative  Tick-borne encephalitis (TBE) is a potentially...      -0.6652
# 27    Neutral  Ticks can carry infections like LymeDisease an...       0.3612
# 28   Positive  The  released a report on lessons learned and ...       0.6369
# 29   Positive  We’re proud members of ’s Business Coalition f...       0.4767
# 30   Positive  DYK immunization is one of the world’s most su...       0.6240
# 31   Positive  Older people make up a majority of those livin...      -0.6597
# 32    Neutral  With the recent acquisition of Amplyx Pharmace...       0.0000
# 33   Positive  Pfizer Medical Information is here to support ...       0.4019
# 34   Positive  Creatives, we’re going live in an hour! Help u...       0.6360
# 35   Positive  Proud to stand alongside so many other committ...       0.6666
# 36   Positive  Proud to join the  lineup for a conversation w...       0.8625
# 37    Neutral  Calling all creatives! Join us tomorrow for th...       0.3595
# 38    Neutral  Tomorrow, Pfizer's Morris Birnbaum, MD, PhD, j...       0.3818
# 39    Neutral  Next month, our Chief Development Officer  wil...       0.5423
# 40   Positive  Today we are proud to be a signatory of IPPACT...       0.6908
# 41   Positive  This “GPS” for the immune system is helping re...       0.5267
# 42   Positive  Our commitment to reducing our environmental i...       0.3818
# 43   Positive  For more than 130 years, we have remained comm...       0.2732
# 44    Neutral  Our Chief Patient Officer, Dr. Dara Richardson...      -0.2263
# 45   Positive  Calling all creatives! We need YOU to design f...       0.3595
# 46   Positive  Today, our own Sandeep Menon joined  &amp; fel...       0.0000
# 47   Positive  Climate Change has a profound impact on human ...       0.5719
# 48   Positive  We’re proud to celebrate Earth Day, and remain...       0.9081
# 49    Neutral  We must stand for equity — as a company and as...       0.5267
#
#     Previsão
# 0     Neutro
# 1   Positivo
# 2     Neutro
# 3     Neutro
# 4   Positivo
# 5     Neutro
# 6     Neutro
# 7   Positivo
# 8   Positivo
# 9     Neutro
# 10  Negativo
# 11  Negativo
# 12  Negativo
# 13  Positivo
# 14    Neutro
# 15  Negativo
# 16  Negativo
# 17    Neutro
# 18  Negativo
# 19    Neutro
# 20  Negativo
# 21    Neutro
# 22    Neutro
# 23    Neutro
# 24    Neutro
# 25  Positivo
# 26  Negativo
# 27    Neutro
# 28    Neutro
# 29    Neutro
# 30    Neutro
# 31  Negativo
# 32  Negativo
# 33    Neutro
# 34    Neutro
# 35    Neutro
# 36  Positivo
# 37    Neutro
# 38    Neutro
# 39    Neutro
# 40    Neutro
# 41    Neutro
# 42    Neutro
# 43    Neutro
# 44  Negativo
# 45    Neutro
# 46  Negativo
# 47    Neutro
# 48  Positivo
# 49    Neutro
